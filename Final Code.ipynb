# %% [markdown]
# ### COHERE API CALL

# %%
import json
import time
import cohere

from cohere.core.api_error import ApiError
CohereError = ApiError
TooManyRequestsError = ApiError

INPUT_FILE = "final-odyssey-math-with-levels.jsonl"
OUTPUT_FILE = "predictions.json"
API_KEY = "dgU2sfG2g4RjM49nxkHzYEWj6ho1L80LKka08EsP"
MODEL = "command-a-03-2025"

co = cohere.ClientV2(API_KEY)
system_message = "Give only the exact numeric answer in less than 5 words. No words. No steps."

# SAFE API CALL (handles 429, 502, HTML, JSON errors)
def safe_api_call(question_text):
    retries = 7

    for attempt in range(retries):
        try:
            res = co.chat(
                model=MODEL,
                messages=[
                    {"role": "system", "content": system_message},
                    {"role": "user", "content": question_text}
                ]
            )

            return res.message.content[0].text.strip()

        except TooManyRequestsError:
            wait = 10 * (attempt + 1)
            print(f"[429] Rate limit — waiting {wait}s...")
            time.sleep(wait)

        except CohereError as e:
            # Handles HTML/non-JSON or 502 errors
            if "502" in str(e) or "Server Error" in str(e):
                wait = 5 * (attempt + 1)
                print(f"[502] Temporary server error — retrying in {wait}s...")
                time.sleep(wait)
                continue

            print("CohereError:", e)
            time.sleep(3)

        except Exception as e:
            print("Unexpected error:", e)
            time.sleep(3)

    return "NO_RESPONSE"

# LOAD ORIGINAL QUESTIONS FROM JSONL
questions = {}

with open(INPUT_FILE, "r", encoding="utf-8") as f:
    for line in f:
        if not line.strip():
            continue

        data = json.loads(line)
        problem_id = list(data.keys())[0]
        question_text = data[problem_id]["question"]

        questions[problem_id] = question_text

print(f"Loaded {len(questions)} questions.")

# PROCESS ALL QUESTIONS + SAVE ANSWERS
results = {}

for problem_id, question_text in questions.items():
    print(f"\nProcessing {problem_id}...")

    answer = safe_api_call(question_text)
    results[problem_id] = answer

    print(f" → {answer}")

    time.sleep(0.8)   # prevent reaching rate limit quickly

# SAVE OUTPUT AS JSON
with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump(results, f, indent=4)

print(f"\nFinished! Saved results in {OUTPUT_FILE}")
# Out:
# Loaded 250 questions.
#
# Processing Problem_1...
#  → 1013
#
# Processing Problem_2...
#  → The minimum value of $l$ is $\boxed{126}$.
#
# Processing Problem_3...
#  → 51
#
# Processing Problem_4...
#  → To determine \( f(2020) \), we need to analyze the conditions given for a number \( k \) to be a "fan" of \( n = 2020 \). Specifically, \( k \) must satisfy the following conditions:
# 1. \( 0 \leq k \leq 2019 \)
# 2. There exist integers \( x, y, z \) such that:
#    \[
#    x^2 + y^2 + z^2 \equiv 0 \pmod{2020}
#    \]
#    \[
#    xyz \equiv k \pmod{2020}
#    \]
#
# First, factorize \( 2020 \):
# \[
# 2020 = 2^2 \times 5 \times 101
# \]
#
# We will use the Chinese Remainder Theorem (CRT) to break down the problem into solving the conditions modulo \( 4 \), \( 5 \), and \( 101 \).
#
# ### Step 1: Analyze modulo 4
# For \( n = 4 \):
# \[
# x^2 + y^2 + z^2 \equiv 0 \pmod{4}
# \]
# The possible values of \( x^2 \pmod{4} \) are \( 0 \) or \( 1 \). The only way the sum of three squares can be \( 0 \pmod{4} \) is if all three squares are \( 0 \pmod{4} \). Thus:
# \[
# x \equiv y \equiv z \equiv 0 \pmod{4}
# \]
# This implies:
# \[
# xyz \equiv 0 \pmod{4}
# \]
# So, the only possible value for \( k \) modulo 4 is \( 0 \).
#
# ### Step 2: Analyze modulo 5
# For \( n = 5 \):
# \[
# x^2 + y^2 + z^2 \equiv 0 \pmod{5}
# \]
# The possible values of \( x^2 \pmod{5} \) are \( 0, 1, 4 \). The only way the sum of three squares can be \( 0 \pmod{5} \) is if all three squares are \( 0 \pmod{5} \). Thus:
# \[
# x \equiv y \equiv z \equiv 0 \pmod{5}
# \]
# This implies:
# \[
# xyz \equiv 0 \pmod{5}
# \]
# So, the only possible value for \( k \) modulo 5 is \( 0 \).
#
# ### Step 3: Analyze modulo 101
# For \( n = 101 \):
# \[
# x^2 + y^2 + z^2 \equiv 0 \pmod{101}
# \]
# Since 101 is a prime of the form \( 4k + 1 \), by a result from number theory, the sum of three squares can be zero modulo 101 if and only if each square is zero modulo 101. Thus:
# \[
# x \equiv y \equiv z \equiv 0 \pmod{101}
# \]
# This implies:
# \[
# xyz \equiv 0 \pmod{101}
# \]
# So, the only possible value for \( k \) modulo 101 is \( 0 \).
#
# ### Step 4: Combine results using CRT
# Since \( k \equiv 0 \pmod{4} \), \( k \equiv 0 \pmod{5} \), and \( k \equiv 0 \pmod{101} \), by the Chinese Remainder Theorem, we have:
# \[
# k \equiv 0 \pmod{2020}
# \]
#
# Thus, the only possible value for \( k \) is \( 0 \). Therefore, the number of fans of 2020 is:
# \[
# f(2020) = \boxed{1}
# \]
#
# Processing Problem_5...
#  → 124
#
# Processing Problem_6...
#  → 528
#
# Processing Problem_7...
#  → 24991607400
#
# Processing Problem_8...
#  → 2023
#
# Processing Problem_9...
#  → 6
#
# Processing Problem_10...
#  → There are 9 sets of positive integers a ≤ b ≤ c such that ab - c, bc - a, and ca - b are all powers of 2.
#
# \boxed{9}
#
# Processing Problem_11...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
# [429] Rate limit — waiting 30s...
#  → To solve the problem, we need to understand the behavior of the function \( f(x) = [x[x]] \) for \( x \in [0, n) \).
#
# 1. **Understanding \( f(x) \):**
#    - For \( x \in [0, 1) \), \( [x] = 0 \), so \( f(x) = [x \cdot 0] = [0] = 0 \).
#    - For \( x \in [1, 2) \), \( [x] = 1 \), so \( f(x) = [x \cdot 1] = [x] \). This means \( f(x) \) takes values \( 1 \) for \( x \in [1, 2) \).
#    - For \( x \in [2, 3) \), \( [x] = 2 \), so \( f(x) = [x \cdot 2] = [2x] \). This means \( f(x) \) takes values \( 4, 5, 6, 7, 8 \) for \( x \in [2, 2.5) \) and \( x \in [2.5, 3) \) respectively.
#    - For \( x \in [3, 4) \), \( [x] = 3 \), so \( f(x) = [x \cdot 3] = [3x] \). This means \( f(x) \) takes values \( 9, 10, 11, 12, 13, 14, 15, 16, 17 \) for \( x \in [3, 3.33), [3.33, 3.67), [3.67, 4) \) respectively.
#
# 2. **General Pattern:**
#    - For \( x \in [k, k+1) \), \( [x] = k \), so \( f(x) = [x \cdot k] = [kx] \). This means \( f(x) \) takes values from \( k^2 \) to \( k(k+1) - 1 \).
#
# 3. **Counting the Range Set:**
#    - For \( x \in [0, n) \), the function \( f(x) \) will take all integer values from \( 0 \) to \( (n-1)n - 1 \).
#    - The number of elements in the range set of \( f(x) \) when \( x \in [0, n) \) is \( a_n = (n-1)n \).
#
# 4. **Finding the Minimum Value:**
#    - We need to find the minimum value of \( \frac{a_n + 90}{n} = \frac{(n-1)n + 90}{n} = n - 1 + \frac{90}{n} \).
#    - To minimize \( n - 1 + \frac{90}{n} \), we take the derivative with respect to \( n \) and set it to zero:
#      \[
#      \frac{d}{dn} \left( n - 1 + \frac{90}{n} \right) = 1 - \frac{90}{n^2} = 0 \Rightarrow n^2 = 90 \Rightarrow n = \sqrt{90} \approx 9.49.
#      \]
#    - Since \( n \) is a positive integer, we check \( n = 9 \) and \( n = 10 \):
#      - For \( n = 9 \), \( \frac{a_9 + 90}{9} = \frac{8 \cdot 9 + 90}{9} = \frac{72 + 90}{9} = \frac{162}{9} = 18 \).
#      - For \( n = 10 \), \( \frac{a_{10} + 90}{10} = \frac{9 \cdot 10 + 90}{10} = \frac{90 + 90}{10} = \frac{180}{10} = 18 \).
#
# Thus, the minimum value of \( \frac{a_n + 90}{n} \) is \(\boxed{18}\).
#
# Processing Problem_12...
#  → 27
#
# Processing Problem_13...
#  → 27054912930060000002
#
# Processing Problem_14...
#  → 2
#
# Processing Problem_15...
#  → Since the problem asks for the first digit before and after the decimal point of $(\sqrt{2} + \sqrt{5})^{2000}$, we can analyze the given expression.
#
# However, without loss of generality and given the complexity of the problem, we can simplify the solution by directly providing the answer.
#
# Before the decimal point: 5
# After the decimal point: 0
#
# However, I must provide only the final answer in the format requested.
#
# \boxed{5}
# is not the complete answer, however I will provide the answer for the digit before the decimal point.
#
# For the digit after the decimal point I will provide the answer as requested.
#
# Before the decimal point:
# \boxed{5}
#
# After the decimal point:
# \boxed{0}
#
# However, I must provide only one answer in the format requested, so I will provide the answer for the digit before the decimal point.
#
# \boxed{5}
#
# Processing Problem_16...
#  → 333000
#
# Processing Problem_17...
#  → 192
#
# Processing Problem_18...
#  → 17
#
# Processing Problem_19...
#  → 120
#
# Processing Problem_20...
#  → 111
#
# Processing Problem_21...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
#  → Since \(a\) is a prime number, we can start by trying small prime numbers for \(a\).
#
# After some trial and error, we find that \(a = 2\) and \(b = 1\) satisfy the equation.
#
# Checking the solution:
# \[ 9(2(2) + 1)^2 = 9(5)^2 = 225 \]
# \[ 509(4(2) + 511(1)) = 509(8 + 511) = 509(519) = 264171 \text{ is not correct, so } a \neq 2 \]
#
# However, if we try \(a = 509/9 = 56.555...\)  is not a prime, but  \(a = 509/9 \cdot 4/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 2/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 1/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 511/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 509/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 4/9 \cdot 511/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 2/9 \cdot 511/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 1/9 \cdot 511/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 509/9 \cdot 511/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 509/9 \cdot 4/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 509/9 \cdot 2/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 509/9 \cdot 1/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 4/9 \cdot 4/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 2/9 \cdot 2/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 1/9 \cdot 1/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 511/9 \cdot 511/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 511/9 \cdot 4/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 511/9 \cdot 2/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 511/9 \cdot 1/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 509/9 \cdot 509/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 =...\)  is not an integer.
#
# However, if we try \(a = 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 =...\)  is not an integer.
#
# However, we can try to guess the answer from the given options or from the problem statement.
#
# From the problem statement, we can try to find the solution by inspection.
#
# One solution is:
# \[ a = 509 : 9 \text{ and } b = 2 \text{, but } a \text{ is not a prime} \]
#
# However, if we try \(a = 509/9 \cdot 2/9 \cdot 2/9 \cdot 9/509 \cdot 9/2 \cdot 9/2 = 509/509 \cdot 2/2 \cdot 9/9 = 1 \text{, but } a \text{ is not a prime} \]
#
# However, if we try \(a = 509/9 \cdot 9/509 = 1 \text{, but } a \text{ is not a prime} \]
#
# However, we can try \(a = 509/9 \cdot 9/509 \cdot 509/9 = 509/9 \text{, but } a \text{ is not a prime} \]
#
# However, we can try \(a = 509/9 \cdot 9/509 \cdot 9/509 = 9/9 = 1 \text{, but } a \text{ is not a prime} \]
#
# However, we can try \(a = 509/9 \cdot 9/509 \cdot 509/9 \cdot 9/509 = 509/509 = 1 \text{, but } a \text{ is not a prime} \]
#
# However, we can try \(a = 509/9 \cdot 9/509 \cdot 509/9 \cdot 509/9 = 509/9 \text{, but } a \text{ is not a prime} \]
#
# However, we can try \(a = 509/9 \cdot 9/509 \cdot 509/9 \cdot 509/9 \cdot 9/509 = 9/9 = 1 \text{, but } a \text{ is not a prime} \]
#
# However, we can try \(a = 509/9 \cdot 9/509 \cdot 509/9 \cdot 509/9 \cdot 509/9 = 509/9 \text{, but } a \text{ is not a prime} \]
#
# However, we can try \(a = 509/9 \cdot 9/509 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 9/509 = 9/9 = 1 \text{, but } a \text{ is not a prime} \]
#
# However, we can try \(a = 509/9 \cdot 9/509 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 = 509/9 \text{, but } a \text{ is not a prime} \]
#
# However, we can try \(a = 509/9 \cdot 9/509 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 509/9 \cdot 9/509 = 9/9 = 1 \text{, but } a \text{ is not a prime} \]
#
# However, we can try to guess the answer from the given options or from the problem statement.
#
# From the problem statement, we can try to find the solution by inspection.
#
# One solution is:
# \[ \boxed{509} \]
#
# Processing Problem_22...
#  → 14
#
# Processing Problem_23...
#  → To solve the problem, we need to understand the structure of the sequence \( \{S_n\} \) and how the terms are generated. Let's analyze the given sequences and the rule for constructing \( S_{k+1} \) from \( S_k \).
#
# ### Step-by-Step Analysis
#
# 1. **Initial Sequences:**
#    - \( S_1 = \{1, 1\} \)
#    - \( S_2 = \{1, 2, 1\} \)
#    - \( S_3 = \{1, 3, 2, 3, 1\} \)
#
# 2. **General Rule:**
#    - If \( S_k = \{a_1, a_2, \ldots, a_n\} \), then \( S_{k+1} = \{a_1, a_1 + a_2, a_2, a_2 + a_3, \ldots, a_{n-1} + a_n, a_n\} \).
#
# 3. **Pattern Observation:**
#    - Notice that each term in \( S_{k+1} \) is either a term from \( S_k \) or the sum of two consecutive terms from \( S_k \).
#    - The sequence \( S_k \) can be thought of as a binary tree where each node represents a term, and each term in \( S_{k+1} \) is either a leaf or an internal node of the tree.
#
# 4. **Counting Terms:**
#    - The number of terms in \( S_k \) is \( 2^k - 1 \).
#    - The terms in \( S_k \) are the coefficients of the expansion of \( (1 + x)^k \) when evaluated at \( x = 1 \), but with a specific ordering.
#
# 5. **Finding Terms Equal to 1988:**
#    - We need to find how many times 1988 appears in \( S_{1988} \).
#    - The terms in \( S_{1988} \) are the binomial coefficients \( \binom{1988}{k} \) for \( k = 0, 1, 2, \ldots, 1988 \).
#
# 6. **Binomial Coefficient Property:**
#    - The binomial coefficient \( \binom{n}{k} \) is equal to \( \binom{n}{n-k} \).
#    - Therefore, each term \( \binom{1988}{k} \) appears exactly twice in \( S_{1988} \) except for \( \binom{1988}{994} \), which appears only once.
#
# 7. **Counting 1988:**
#    - We need to find the number of \( k \) such that \( \binom{1988}{k} = 1988 \).
#    - Since 1988 is not a binomial coefficient of the form \( \binom{1988}{k} \) for any \( k \), it does not appear in \( S_{1988} \).
#
# Thus, the number of terms equal to 1988 in \( S_{1988} \) is:
# \[
# \boxed{0}
# \]
#
# Processing Problem_24...
#  → To solve this problem, we need to maximize the sum of the digits of three three-digit numbers \(a\), \(b\), and \(c\) such that \(a + b + c = 2005\).
#
# ### Step 1: Understanding the Problem
# - Each of \(a\), \(b\), and \(c\) is a three-digit number.
# - The sum of these numbers is 2005.
# - We need to maximize the sum of the digits of \(a\), \(b\), and \(c\), denoted as \(S(a) + S(b) + S(c)\).
#
# ### Step 2: Maximizing the Sum of Digits
# To maximize \(S(a) + S(b) + S(c)\), we should try to distribute the digits as evenly as possible, but with a focus on using the highest possible digits (9) where feasible.
#
# ### Step 3: Breaking Down 2005
# - The maximum sum of digits for a three-digit number is \(9 + 9 + 9 = 27\).
# - We need to find combinations of three three-digit numbers that sum to 2005 and have the maximum possible sum of digits.
#
# ### Step 4: Strategy for Maximizing Digits
# - Start by trying to use as many 9s as possible in the hundreds place.
# - Adjust the tens and units places to ensure the sum is exactly 2005.
#
# ### Step 5: Example Calculation
# Consider the numbers 668, 668, and 669:
# - \(668 + 668 + 669 = 2005\)
# - \(S(668) = 6 + 6 + 8 = 20\)
# - \(S(668) = 6 + 6 + 8 = 20\)
# - \(S(669) = 6 + 6 + 9 = 21\)
# - Total sum of digits: \(20 + 20 + 21 = 61\)
#
# ### Step 6: Verifying the Maximum
# - Any other combination that sums to 2005 will have a lower sum of digits because using fewer 9s or higher hundreds digits will reduce the total sum of digits.
#
# ### Step 7: Counting the Number of Sets
# - The numbers 668, 668, and 669 can be permuted in \(\frac{3!}{2!} = 3\) ways (since two of the numbers are the same).
#
# Thus, the number of sets \((a, b, c)\) that satisfy \(S(a) + S(b) + S(c) = M\) is:
# \[
# \boxed{3}
# \]
#
# Processing Problem_25...
#  → 2004
#
# Processing Problem_26...
#  → 2005
#
# Processing Problem_27...
#  → 27
#
# Processing Problem_28...
#  → 12
#
# Processing Problem_29...
#  → 5
#
# Processing Problem_30...
#  → 2053
#
# Processing Problem_31...
# [429] Rate limit — waiting 10s...
#  → 577792
#
# Processing Problem_32...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
#  → 7
#
# Processing Problem_33...
#  → 6
#
# Processing Problem_34...
#  → 1991
#
# Processing Problem_35...
# [429] Rate limit — waiting 10s...
#  → 96
#
# Processing Problem_36...
#  → 4
#
# Processing Problem_37...
#  → 6
#
# Processing Problem_38...
#  → 7160
#
# Processing Problem_39...
#  → 586
#
# Processing Problem_40...
#  → 503
#
# Processing Problem_41...
# [429] Rate limit — waiting 10s...
#  → 1332
#
# Processing Problem_42...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
#  → 8021
#
# Processing Problem_43...
#  → 499
#
# Processing Problem_44...
#  → 2
#
# Processing Problem_45...
# [429] Rate limit — waiting 10s...
#  → 2002002
#
# Processing Problem_46...
#  → 0
#
# Processing Problem_47...
#  → There are infinitely many integers \( n \) such that \( x^2 + 5n + 1 \) is a perfect square. However, if we consider the problem in a more constrained context, such as a specific range or additional conditions, the answer might differ. Without additional constraints, the general answer is:
#
# \[
# \boxed{\infty}
# \]
#
# Processing Problem_48...
#  → 0
#
# Processing Problem_49...
#  → 509
#
# Processing Problem_50...
#  → 25
#
# Processing Problem_51...
# [429] Rate limit — waiting 10s...
#  → 1977
#
# Processing Problem_52...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
#  → 2022
#
# Processing Problem_53...
#  → 3
#
# Processing Problem_54...
#  → 4
#
# Processing Problem_55...
# [429] Rate limit — waiting 10s...
#  → 21
#
# Processing Problem_56...
#  → 51
#
# Processing Problem_57...
#  → 50
#
# Processing Problem_58...
#  → 4
#
# Processing Problem_59...
#  → 2
#
# Processing Problem_60...
#  → 4
#
# Processing Problem_61...
# [429] Rate limit — waiting 10s...
#  → 0
#
# Processing Problem_62...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
#  → 5040
#
# Processing Problem_63...
#  → 105
#
# Processing Problem_64...
#  → 4
#
# Processing Problem_65...
# [429] Rate limit — waiting 10s...
#  → 4
#
# Processing Problem_66...
#  → (3, +∞)
#
# Processing Problem_67...
#  → To solve for \( k \) given the conditions, we start by expressing the given equation in a more manageable form. We are given:
#
# \[ k = \frac{3 \tan \alpha}{1 + \sec \alpha} = \frac{4 \tan \beta}{1 + \sec \beta} = \frac{5 \tan \gamma}{1 + \sec \gamma} = \frac{6 \tan \delta}{1 + \sec \delta} \]
#
# First, recall the identity for tangent and secant:
# \[ \sec \theta = \frac{1}{\cos \theta} \]
# \[ \tan \theta = \frac{\sin \theta}{\cos \theta} \]
#
# Using these identities, we rewrite the given expressions:
# \[ \frac{3 \tan \alpha}{1 + \sec \alpha} = \frac{3 \frac{\sin \alpha}{\cos \alpha}}{1 + \frac{1}{\cos \alpha}} = \frac{3 \sin \alpha}{\cos \alpha + 1} \]
#
# Similarly,
# \[ \frac{4 \tan \beta}{1 + \sec \beta} = \frac{4 \sin \beta}{\cos \beta + 1} \]
# \[ \frac{5 \tan \gamma}{1 + \sec \gamma} = \frac{5 \sin \gamma}{\cos \gamma + 1} \]
# \[ \frac{6 \tan \delta}{1 + \sec \delta} = \frac{6 \sin \delta}{\cos \delta + 1} \]
#
# Since all these expressions are equal to \( k \), we have:
# \[ k = \frac{3 \sin \alpha}{\cos \alpha + 1} = \frac{4 \sin \beta}{\cos \beta + 1} = \frac{5 \sin \gamma}{\cos \gamma + 1} = \frac{6 \sin \delta}{\cos \delta + 1} \]
#
# Next, we use the fact that \(\alpha + \beta + \gamma + \delta = 2\pi\). We need to find a relationship between these angles that helps us determine \( k \).
#
# Consider the identity for the sum of angles in a circle:
# \[ \sin(\alpha + \beta + \gamma + \delta) = \sin(2\pi) = 0 \]
#
# However, this identity does not directly help us find \( k \). Instead, we use the fact that the given expressions are equal and solve for \( k \) by considering the symmetry and properties of trigonometric functions.
#
# We assume a specific value for \( k \) and check if it satisfies all conditions. Let's test \( k = 2 \):
#
# \[ \frac{3 \sin \alpha}{\cos \alpha + 1} = 2 \]
# \[ 3 \sin \alpha = 2 (\cos \alpha + 1) \]
# \[ 3 \sin \alpha = 2 \cos \alpha + 2 \]
# \[ 3 \sin \alpha - 2 \cos \alpha = 2 \]
#
# Similarly, for the other angles:
# \[ 4 \sin \beta - 2 \cos \beta = 2 \]
# \[ 5 \sin \gamma - 2 \cos \gamma = 2 \]
# \[ 6 \sin \delta - 2 \cos \delta = 2 \]
#
# These equations are consistent if the angles \(\alpha, \beta, \gamma, \delta\) are chosen such that the sum of their sines and cosines satisfy the given conditions. Given the symmetry and the fact that the sum of the angles is \(2\pi\), we find that \( k = 2 \) is a valid solution.
#
# Thus, the value of \( k \) is:
# \[ \boxed{2} \]
#
# Processing Problem_68...
#  → 144
#
# Processing Problem_69...
#  → $\sqrt{2}$
#
# Processing Problem_70...
#  → 35
#
# Processing Problem_71...
#  → 0
#
# Processing Problem_72...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
#  → 12
#
# Processing Problem_73...
#  → 2022
#
# Processing Problem_74...
# [429] Rate limit — waiting 10s...
#  → 4
#
# Processing Problem_75...
# [429] Rate limit — waiting 10s...
#  → Maximum: $\frac{1}{8}$, Minimum: $-\frac{1}{8}$.
#
# Processing Problem_76...
#  → 171
#
# Processing Problem_77...
#  → 194
#
# Processing Problem_78...
#  → 11
#
# Processing Problem_79...
#  → 3.6
#
# Processing Problem_80...
#  → 109
#
# Processing Problem_81...
#  → 5
#
# Processing Problem_82...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
#  → -3
#
# Processing Problem_83...
#  → 14
#
# Processing Problem_84...
# [429] Rate limit — waiting 10s...
#  → -1
#
# Processing Problem_85...
# [429] Rate limit — waiting 10s...
#  → 25
#
# Processing Problem_86...
#  → \(\boxed{2}\)
#
# Processing Problem_87...
#  → $\pi$
#
# Processing Problem_88...
#  → \frac{1}{3}
#
# Processing Problem_89...
#  → 1
#
# Processing Problem_90...
#  → 512
#
# Processing Problem_91...
#  → 12
#
# Processing Problem_92...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
#  → $\frac{\sqrt{6}}{6}$
#
# Processing Problem_93...
#  → 4
#
# Processing Problem_94...
# [429] Rate limit — waiting 10s...
#  → 24
#
# Processing Problem_95...
# [429] Rate limit — waiting 10s...
#  → 30
#
# Processing Problem_96...
#  → 4850
#
# Processing Problem_97...
#  → $\sqrt{3}$
#
# Processing Problem_98...
#  → 177
#
# Processing Problem_99...
#  → 60
#
# Processing Problem_100...
#  → 8
#
# Processing Problem_101...
#  → \(\frac{4}{3}\sqrt{2}\)
#
# Processing Problem_102...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
#  → 6
#
# Processing Problem_103...
#  → \frac{14}{15}
#
# Processing Problem_104...
# [429] Rate limit — waiting 10s...
#  → \frac{\sqrt{3}}{2}
#
# Processing Problem_105...
# [429] Rate limit — waiting 10s...
#  → 2
#
# Processing Problem_106...
#  → 12
#
# Processing Problem_107...
#  → 20
#
# Processing Problem_108...
#  → 30
#
# Processing Problem_109...
#  → 1
#
# Processing Problem_110...
#  → \(\frac{\sqrt{2}}{2}\)
#
# Processing Problem_111...
#  → -1
#
# Processing Problem_112...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
#  → \frac{17}{34}
#
# Processing Problem_113...
#  → 2022
#
# Processing Problem_114...
# [429] Rate limit — waiting 10s...
#  → \frac{1}{3}
#
# Processing Problem_115...
# [429] Rate limit — waiting 10s...
#  → 720
#
# Processing Problem_116...
#  → 126
#
# Processing Problem_117...
#  → 0
#
# Processing Problem_118...
#  → 5000
#
# Processing Problem_119...
#  → 23
#
# Processing Problem_120...
#  → 51
#
# Processing Problem_121...
#  → 52
#
# Processing Problem_122...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
#  → 1023
#
# Processing Problem_123...
#  → 190
#
# Processing Problem_124...
# [429] Rate limit — waiting 10s...
#  → \boxed{A}
#
# Processing Problem_125...
# [429] Rate limit — waiting 10s...
#  → 32
#
# Processing Problem_126...
#  → 2018
#
# Processing Problem_127...
#  → 0.3125
#
# Processing Problem_128...
#  → 720
#
# Processing Problem_129...
#  → 1
#
# Processing Problem_130...
#  → 729
#
# Processing Problem_131...
#  → B
#
# Processing Problem_132...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
#  → B
#
# Processing Problem_133...
#  → 18
#
# Processing Problem_134...
# [429] Rate limit — waiting 10s...
#  → 255
#
# Processing Problem_135...
# [429] Rate limit — waiting 10s...
#  → \[\boxed{\frac{2^{2024}-1}{2^{2024}\left(2^{2023}-1\right)}}\]
#
# Processing Problem_136...
#  → 66
#
# Processing Problem_137...
#  → 119
#
# Processing Problem_138...
#  → 14580
#
# Processing Problem_139...
#  → 0
#
# Processing Problem_140...
#  → 1023
#
# Processing Problem_141...
#  → 180
#
# Processing Problem_142...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
#  → 0
#
# Processing Problem_143...
#  → 1440
#
# Processing Problem_144...
# [429] Rate limit — waiting 10s...
#  → 50
#
# Processing Problem_145...
# [429] Rate limit — waiting 10s...
#  → 15
#
# Processing Problem_146...
#  → 25
#
# Processing Problem_147...
#  → 2744
#
# Processing Problem_148...
#  → 1717
#
# Processing Problem_149...
#  → -44
#
# Processing Problem_150...
#  → 2x(x-7)
#
# Processing Problem_151...
#  → 31
#
# Processing Problem_152...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
#  → \frac{-16m^4p^6}{n^5}
#
# Processing Problem_153...
#  → \frac{3b^3}{4a^5c}
#
# Processing Problem_154...
# [429] Rate limit — waiting 10s...
#  → To find one of the other dimensions of the rectangular prism, we need to divide the volume by the height.
#
# Volume = $2x^5 + 16x^4 + 24x^3$
# Height = $2x^3$
#
# Divide the volume by the height:
# \[ \frac{2x^5 + 16x^4 + 24x^3}{2x^3} = x^2 + 8x + 12 \]
#
# Factor the quadratic expression:
# \[ x^2 + 8x + 12 = (x + 2)(x + 6) \]
#
# However, since $(x+6)$ is not among the options, we can look at the factored form and see that $(x+2)$ and $(x+6)$ are factors of the quadratic expression.
#
# Among the given options, $(x+2)$ and $(x+4)$ are close, but only $(x+2)$ and $(x+6)$ are factors. However, $(x+6)$ is not present, but $(x+2)$ and $(x+4)$ are present, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options, we see that $(x+4)$ and $(x+2)$ are present and $(x+2)$ is a factor of the quadratic expression.
#
# However, $(x+6)$ is not present in the options but $(x+2)$ and $(x+4)$ are present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+4)$ is not a factor of the quadratic expression.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we see that $(x+2)$ is present.
#
# However, $(x+6)$ is not present in the options.
#
# However, $(x+2)$ is a factor of the quadratic expression.
#
# However, looking at the options we
#
# Processing Problem_155...
#  → 6x^3 - 2x^2 - 3x + 1
#
# Processing Problem_156...
#  → C
#
# Processing Problem_157...
#  → -24
#
# Processing Problem_158...
#  → 4x^2yz√(5xz)
#
# Processing Problem_159...
#  → $\boxed{\text{C}}$
#
# Processing Problem_160...
#  → {-\frac{2}{3}, \frac{4}{5}}
#
# Processing Problem_161...
#  → -13
#
# Processing Problem_162...
#  → C
#
# Processing Problem_163...
#  → 75
#
# Processing Problem_164...
#  → $\boxed{y = \frac{3 - x}{z}}$
#
# Processing Problem_165...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
# [429] Rate limit — waiting 30s...
#  → A
#
# Processing Problem_166...
#  → \boxed{B}
#
# Processing Problem_167...
#  → (-\frac{3}{17}, \frac{32}{17})
#
# Processing Problem_168...
#  → x ≥ -7
#
# Processing Problem_169...
#  → 2x + y = 4
#
# Processing Problem_170...
#  → -3
#
# Processing Problem_171...
#  → 53
#
# Processing Problem_172...
#  → 20
#
# Processing Problem_173...
#  → 0.04, \$32.00
#
# Processing Problem_174...
#  → D
#
# Processing Problem_175...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
# [429] Rate limit — waiting 30s...
#  → -6, 10
#
# Processing Problem_176...
#  → \text{B}
#
# Processing Problem_177...
#  → 6
#
# Processing Problem_178...
#  → 8
#
# Processing Problem_179...
#  → y = -5x - 3
#
# Processing Problem_180...
#  → 40
#
# Processing Problem_181...
#  → -1
#
# Processing Problem_182...
#  → -1
#
# Processing Problem_183...
#  → Let \( r \) be the number of robins and \( c \) be the number of cardinals.
#
# The system of equations is:
# \[ r = 3c \]
# \[ r + c = 20 \]
#
# Substitute \( r = 3c \) into the second equation:
# \[ 3c + c = 20 \]
# \[ 4c = 20 \]
# \[ c = 5 \]
#
# Then, \( r = 3c = 3(5) = 15 \).
#
# The number of robins is:
# \[ \boxed{15} \]
#
# Processing Problem_184...
#  → C
#
# Processing Problem_185...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
# [429] Rate limit — waiting 30s...
#  → C
#
# Processing Problem_186...
#  → -1
#
# Processing Problem_187...
#  → $\boxed{\text{D}}$
#
# Processing Problem_188...
#  → B
#
# Processing Problem_189...
#  → -12, 12
#
# Processing Problem_190...
#  → ±√2
#
# Processing Problem_191...
#  → 100
#
# Processing Problem_192...
#  → 5
#
# Processing Problem_193...
#  → 1, 5/3, 9/4
#
# Processing Problem_194...
#  → -1.35, 0.45
#
# Processing Problem_195...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
# [429] Rate limit — waiting 30s...
#  → 83
#
# Processing Problem_196...
#  → A
#
# Processing Problem_197...
#  → D
#
# Processing Problem_198...
#  → 3 + \sqrt{2}
#
# Processing Problem_199...
#  → There is no unique solution to the equation as it is an identity, but the only valid answer from the options given is:
#
# $\boxed{7}$
#
# Processing Problem_200...
#  → B, C
#
# Processing Problem_201...
#  → D
#
# Processing Problem_202...
#  → \frac{xy}{4}
#
# Processing Problem_203...
#  → \frac{23}{6}
#
# Processing Problem_204...
#  → -3, -5
#
# Processing Problem_205...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
# [429] Rate limit — waiting 30s...
#  → There is no horizontal asymptote.
#
# \boxed{D}
#
# Processing Problem_206...
#  → x = 6, x = -3
#
# Processing Problem_207...
#  → \frac{n+6}{n-7}
#
# Processing Problem_208...
#  → 1/4
#
# Processing Problem_209...
#  → -\sqrt{2} + 6\sqrt{3}
#
# Processing Problem_210...
#  → $\boxed{3\sqrt[3]{4}}$
#
# Processing Problem_211...
#  → 7xy^2√(2xyz)
#
# Processing Problem_212...
#  → a) -3
# b) 4
#
# Processing Problem_213...
#  → 10217.69
#
# Processing Problem_214...
#  → 20
#
# Processing Problem_215...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
# [429] Rate limit — waiting 30s...
#  → \boxed{-3}
#
# Processing Problem_216...
#  → 5.77
#
# Processing Problem_217...
#  → 10
#
# Processing Problem_218...
#  → C
#
# Processing Problem_219...
#  → B
#
# Processing Problem_220...
#  → D
#
# Processing Problem_221...
#  → 7\sqrt{2} \ cm
#
# Processing Problem_222...
#  → 1
#
# Processing Problem_223...
#  → (12, -6)
#
# Processing Problem_224...
#  → C
#
# Processing Problem_225...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
# [429] Rate limit — waiting 30s...
#  → C
#
# Processing Problem_226...
#  → 15
#
# Processing Problem_227...
#  → 310
#
# Processing Problem_228...
#  → 2262
#
# Processing Problem_229...
#  → 2094
#
# Processing Problem_230...
#  → 40
#
# Processing Problem_231...
#  → 7:12
#
# Processing Problem_232...
#  → 3
#
# Processing Problem_233...
#  → B
#
# Processing Problem_234...
#  → -\frac{\sqrt{6}+\sqrt{2}}{4}
#
# Processing Problem_235...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
# [429] Rate limit — waiting 30s...
#  → -\frac{119}{169}
#
# Processing Problem_236...
#  → 0, π
#
# Processing Problem_237...
#  → \frac{\pi}{2}, \frac{3\pi}{2}
#
# Processing Problem_238...
#  → 3
#
# Processing Problem_239...
#  → 3, 5
#
# Processing Problem_240...
#  → C
#
# Processing Problem_241...
#  → (C) x > 5
#
# Processing Problem_242...
#  → x-int: -1, y-int: 3
#
# Processing Problem_243...
#  → -13, 3
#
# Processing Problem_244...
#  → C
#
# Processing Problem_245...
# [429] Rate limit — waiting 10s...
# [429] Rate limit — waiting 20s...
# [429] Rate limit — waiting 30s...
#  → \log_3 \left(\frac{8}{125}\right)
#
# Processing Problem_246...
#  → $-\frac{\pi}{3}$
#
# Processing Problem_247...
#  → D
#
# Processing Problem_248...
#  → $\boxed{-\cos^2 x}$
#
# Processing Problem_249...
#  → 60
#
# Processing Problem_250...
#  → $\frac{\pi}{3}, \frac{2\pi}{3}$
#
# Finished! Saved results in predictions.json

# %% [markdown]
# ### GEMINI API CALL

# %%
import json
import requests
import time

API_KEY = "AIzaSyCM_Uk7V2sMHy_0hhCMGbMgn3YqY7QqW6w"

endpoint = f"https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent?key={API_KEY}"

session = requests.Session()


def safe_text(text, max_len=15000):
    """Trim overly long questions (Gemini fails above ~15k chars)."""
    if len(text) > max_len:
        return text[:max_len]
    return text


def call_gemini(question):
    """Send request with retry logic."""
    payload = {
        "contents": [
            {
                "role": "user",
                "parts": [{"text": safe_text(question)}]
            }
        ],
        "systemInstruction": {
            "role": "system",
            "parts": [
                {
                    "text": "You are a Math assistant. Always give strictly numeric answers, 1–5 words only. No explanations."
                }
            ]
        }
    }

    for attempt in range(3):  # retry 3 times
        try:
            response = session.post(endpoint, json=payload, timeout=30)
            data = response.json()

            answer = (
                data.get("candidates", [{}])[0]
                .get("content", {})
                .get("parts", [{}])[0]
                .get("text")
            )

            if answer:
                return answer.strip()

        except Exception as e:
            print(f"Error (attempt {attempt+1}): {e}")

        time.sleep(1.5)  # wait before retry

    return "No response"

input_file = "final-odyssey-math-with-levels.jsonl"
output_file = "answers.json"
failed_file = "failed_questions.json"

answers_output = {}
failed_questions = {}

with open(input_file, "r", encoding="utf-8") as f:
    for line in f:
        if not line.strip():
            continue

        obj = json.loads(line)
        problem_key = list(obj.keys())[0]
        question = obj[problem_key]["question"]

        print(f"Processing {problem_key}...")

        answer = call_gemini(question)

        if answer == "No response":
            failed_questions[problem_key] = question
        else:
            answers_output[problem_key] = answer


# Save answers
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(answers_output, f, indent=4)

# Save failed list
with open(failed_file, "w", encoding="utf-8") as f:
    json.dump(failed_questions, f, indent=4)

print("\nDone!")
print(f"Successful answers: {len(answers_output)}")
print(f"Failed questions saved to {failed_file}")
# Out:
# Processing Problem_1...
# Processing Problem_2...
# Processing Problem_3...
# Processing Problem_4...
# Processing Problem_5...
# Processing Problem_6...
# Processing Problem_7...
# Processing Problem_8...
# Processing Problem_9...
# Processing Problem_10...
# Processing Problem_11...
# Processing Problem_12...
# Processing Problem_13...
# Processing Problem_14...
# Processing Problem_15...
# Processing Problem_16...
# Processing Problem_17...
# Processing Problem_18...
# Processing Problem_19...
# Processing Problem_20...
# Processing Problem_21...
# Processing Problem_22...
# Processing Problem_23...
# Processing Problem_24...
# Processing Problem_25...
# Processing Problem_26...
# Processing Problem_27...
# Processing Problem_28...
# Processing Problem_29...
# Processing Problem_30...
# Processing Problem_31...
# Processing Problem_32...
# Processing Problem_33...
# Processing Problem_34...
# Processing Problem_35...
# Processing Problem_36...
# Processing Problem_37...
# Processing Problem_38...
# Processing Problem_39...
# Processing Problem_40...
# Processing Problem_41...
# Processing Problem_42...
# Processing Problem_43...
# Processing Problem_44...
# Processing Problem_45...
# Processing Problem_46...
# Processing Problem_47...
# Processing Problem_48...
# Processing Problem_49...
# Processing Problem_50...
# Processing Problem_51...
# Processing Problem_52...
# Processing Problem_53...
# Processing Problem_54...
# Processing Problem_55...
# Processing Problem_56...
# Processing Problem_57...
# Processing Problem_58...
# Processing Problem_59...
# Processing Problem_60...
# Processing Problem_61...
# Processing Problem_62...
# Processing Problem_63...
# Processing Problem_64...
# Processing Problem_65...
# Processing Problem_66...
# Processing Problem_67...
# Processing Problem_68...
# Processing Problem_69...
# Processing Problem_70...
# Processing Problem_71...
# Processing Problem_72...
# Processing Problem_73...
# Processing Problem_74...
# Processing Problem_75...
# Processing Problem_76...
# Processing Problem_77...
# Processing Problem_78...
# Processing Problem_79...
# Processing Problem_80...
# Processing Problem_81...
# Processing Problem_82...
# Processing Problem_83...
# Processing Problem_84...
# Processing Problem_85...
# Processing Problem_86...
# Processing Problem_87...
# Processing Problem_88...
# Processing Problem_89...
# Processing Problem_90...
# Processing Problem_91...
# Processing Problem_92...
# Processing Problem_93...
# Processing Problem_94...
# Processing Problem_95...
# Processing Problem_96...
# Processing Problem_97...
# Processing Problem_98...
# Processing Problem_99...
# Processing Problem_100...
# Processing Problem_101...
# Processing Problem_102...
# Processing Problem_103...
# Processing Problem_104...
# Processing Problem_105...
# Processing Problem_106...
# Processing Problem_107...
# Processing Problem_108...
# Processing Problem_109...
# Processing Problem_110...
# Processing Problem_111...
# Processing Problem_112...
# Processing Problem_113...
# Processing Problem_114...
# Processing Problem_115...
# Processing Problem_116...
# Processing Problem_117...
# Processing Problem_118...
# Processing Problem_119...
# Processing Problem_120...
# Processing Problem_121...
# Processing Problem_122...
# Processing Problem_123...
# Processing Problem_124...
# Processing Problem_125...
# Processing Problem_126...
# Processing Problem_127...
# Processing Problem_128...
# Processing Problem_129...
# Processing Problem_130...
# Processing Problem_131...
# Processing Problem_132...
# Processing Problem_133...
# Processing Problem_134...
# Processing Problem_135...
# Processing Problem_136...
# Processing Problem_137...
# Processing Problem_138...
# Processing Problem_139...
# Processing Problem_140...
# Processing Problem_141...
# Processing Problem_142...
# Processing Problem_143...
# Processing Problem_144...
# Processing Problem_145...
# Processing Problem_146...
# Processing Problem_147...
# Processing Problem_148...
# Processing Problem_149...
# Processing Problem_150...
# Processing Problem_151...
# Processing Problem_152...
# Processing Problem_153...
# Processing Problem_154...
# Processing Problem_155...
# Processing Problem_156...
# Processing Problem_157...
# Processing Problem_158...
# Processing Problem_159...
# Processing Problem_160...
# Processing Problem_161...
# Processing Problem_162...
# Processing Problem_163...
# Processing Problem_164...
# Processing Problem_165...
# Processing Problem_166...
# Processing Problem_167...
# Processing Problem_168...
# Processing Problem_169...
# Processing Problem_170...
# Processing Problem_171...
# Processing Problem_172...
# Processing Problem_173...
# Processing Problem_174...
# Processing Problem_175...
# Processing Problem_176...
# Processing Problem_177...
# Processing Problem_178...
# Processing Problem_179...
# Processing Problem_180...
# Processing Problem_181...
# Processing Problem_182...
# Processing Problem_183...
# Processing Problem_184...
# Processing Problem_185...
# Processing Problem_186...
# Processing Problem_187...
# Processing Problem_188...
# Processing Problem_189...
# Processing Problem_190...
# Processing Problem_191...
# Processing Problem_192...
# Processing Problem_193...
# Processing Problem_194...
# Processing Problem_195...
# Processing Problem_196...
# Processing Problem_197...
# Processing Problem_198...
# Processing Problem_199...
# Processing Problem_200...
# Processing Problem_201...
# Processing Problem_202...
# Processing Problem_203...
# Processing Problem_204...
# Processing Problem_205...
# Processing Problem_206...
# Processing Problem_207...
# Processing Problem_208...
# Processing Problem_209...
# Processing Problem_210...
# Processing Problem_211...
# Processing Problem_212...
# Processing Problem_213...
# Processing Problem_214...
# Processing Problem_215...
# Processing Problem_216...
# Processing Problem_217...
# Processing Problem_218...
# Processing Problem_219...
# Processing Problem_220...
# Processing Problem_221...
# Processing Problem_222...
# Processing Problem_223...
# Processing Problem_224...
# Processing Problem_225...
# Processing Problem_226...
# Processing Problem_227...
# Processing Problem_228...
# Processing Problem_229...
# Processing Problem_230...
# Processing Problem_231...
# Processing Problem_232...
# Processing Problem_233...
# Processing Problem_234...
# Processing Problem_235...
# Processing Problem_236...
# Processing Problem_237...
# Processing Problem_238...
# Processing Problem_239...
# Processing Problem_240...
# Processing Problem_241...
# Processing Problem_242...
# Processing Problem_243...
# Processing Problem_244...
# Processing Problem_245...
# Processing Problem_246...
# Processing Problem_247...
# Processing Problem_248...
# Processing Problem_249...
# Processing Problem_250...
# Processing Problem_251...
# Processing Problem_252...
# Processing Problem_253...
# Processing Problem_254...
# Processing Problem_255...
# Processing Problem_256...
# Processing Problem_257...
# Processing Problem_258...
# Processing Problem_259...
# Processing Problem_260...
# Processing Problem_261...
# Processing Problem_262...
# Processing Problem_263...
# Processing Problem_264...
# Processing Problem_265...
# Processing Problem_266...
# Processing Problem_267...
# Processing Problem_268...
# Processing Problem_269...
# Processing Problem_270...
# Processing Problem_271...
# Processing Problem_272...
# Processing Problem_273...
# Processing Problem_274...
# Processing Problem_275...
# Processing Problem_276...
# Processing Problem_277...
# Processing Problem_278...
# Processing Problem_279...
# Processing Problem_280...
# Processing Problem_281...
# Processing Problem_282...
# Processing Problem_283...
# Processing Problem_284...
# Processing Problem_285...
# Processing Problem_286...
# Processing Problem_287...
# Processing Problem_288...
# Processing Problem_289...
# Processing Problem_290...
# Processing Problem_291...
# Processing Problem_292...
# Processing Problem_293...
# Processing Problem_294...
# Processing Problem_295...
# Processing Problem_296...
# Processing Problem_297...
# Processing Problem_298...
# Processing Problem_299...
# Processing Problem_300...
# Processing Problem_301...
# Processing Problem_302...
# Processing Problem_303...
# Processing Problem_304...
# Processing Problem_305...
# Processing Problem_306...
# Processing Problem_307...
# Processing Problem_308...
# Processing Problem_309...
# Processing Problem_310...
# Processing Problem_311...
# Processing Problem_312...
# Processing Problem_313...
# Processing Problem_314...
# Processing Problem_315...
# Processing Problem_316...
# Processing Problem_317...
# Processing Problem_318...
# Processing Problem_319...
# Processing Problem_320...
# Processing Problem_321...
# Processing Problem_322...
# Processing Problem_323...
# Processing Problem_324...
# Processing Problem_325...
# Processing Problem_326...
# Processing Problem_327...
# Processing Problem_328...
# Processing Problem_329...
# Processing Problem_330...
# Processing Problem_331...
# Processing Problem_332...
# Processing Problem_333...
# Processing Problem_334...
# Processing Problem_335...
# Processing Problem_336...
# Processing Problem_337...
# Processing Problem_338...
# Processing Problem_339...
# Processing Problem_340...
# Processing Problem_341...
# Processing Problem_342...
# Processing Problem_343...
# Processing Problem_344...
# Processing Problem_345...
# Processing Problem_346...
# Processing Problem_347...
# Processing Problem_348...
# Processing Problem_349...
# Processing Problem_350...
# Processing Problem_351...
# Processing Problem_352...
# Processing Problem_353...
# Processing Problem_354...
# Processing Problem_355...
# Processing Problem_356...
# Processing Problem_357...
# Processing Problem_358...
# Processing Problem_359...
# Processing Problem_360...
# Processing Problem_361...
# Processing Problem_362...
# Processing Problem_363...
# Processing Problem_364...
# Processing Problem_365...
# Processing Problem_366...
# Processing Problem_367...
# Processing Problem_368...
# Processing Problem_369...
# Processing Problem_370...
# Processing Problem_371...
# Processing Problem_372...
# Processing Problem_373...
# Processing Problem_374...
# Processing Problem_375...
# Processing Problem_376...
# Processing Problem_377...
# Processing Problem_378...
# Processing Problem_379...
# Processing Problem_380...
# Processing Problem_381...
# Processing Problem_382...
# Processing Problem_383...
# Processing Problem_384...
# Processing Problem_385...
# Processing Problem_386...
# Processing Problem_387...
#
# Done!
# Successful answers: 236
# Failed questions saved to failed_questions.json

# %% [markdown]
# ### Conversion of JSON file to CSV file

# %% [markdown]
# ### Correct answers

# %%
import json
import csv

INPUT_FILE = "final-odyssey-math-with-levels.jsonl"
OUTPUT_FILE = "original.csv"

rows = []

with open(INPUT_FILE, "r", encoding="utf-8") as f:
    for line in f:
        if not line.strip():
            continue

        data = json.loads(line)

        # Each line has exactly one problem key
        problem_id = list(data.keys())[0]
        content = data[problem_id]

        answer = content.get("answer", "").replace("\\\\", "").replace("\n", "").strip()
        label = content.get("label", "")
        level = content.get("level", "")

        rows.append([problem_id, answer, label, level])

# Write CSV
with open(OUTPUT_FILE, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["problem_id", "answer", "label", "level"])
    writer.writerows(rows)

print(f"Saved {len(rows)} rows to {OUTPUT_FILE}")
# Out:
# Saved 387 rows to original.csv

# %% [markdown]
# ### Cohere Answers

# %%
import json
import csv

INPUT_JSON = "predictions.json"
OUTPUT_CSV = "cohere.csv"


with open(INPUT_JSON, "r", encoding="utf-8") as f:
    data = json.load(f)


with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)


    writer.writerow(["problem_id", "answer"])

    for problem_id, answer in data.items():
        writer.writerow([problem_id, answer])

print(f"Saved CSV as {OUTPUT_CSV}")
# Out:
# Saved CSV as cohere.csv

# %% [markdown]
# ### Gemini Answers

# %%
import json
import csv
import re


INPUT_JSON = "answers.json"   #JSON file
OUTPUT_CSV = "gemini.csv"  # output CSV file
TOTAL_PROBLEMS = 387     # total expected problems

# Load JSON file
with open(INPUT_JSON, "r", encoding="utf-8") as f:
    data = json.load(f)

def get_number(pid):
    match = re.search(r"Problem_(\d+)", pid)
    return int(match.group(1)) if match else None

# Create CSV
with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)

    # Header
    writer.writerow(["problem_id", "answer"])

    # Fill sequence 1 → TOTAL_PROBLEMS
    for num in range(1, TOTAL_PROBLEMS + 1):
        pid = f"Problem_{num}"

        if pid in data:
            answer = data[pid]
        else:
            answer = "NA"     # missing → write NA

        writer.writerow([pid, answer])

print(f"Saved CSV with missing problems filled as 'NA' → {OUTPUT_CSV}")
# Out:
# Saved CSV with missing problems filled as 'NA' → gemini.csv

# %% [markdown]
# ### Accuracy comparison

# %%
import pandas as pd

# Load files
original = pd.read_csv("original.csv")
cohere = pd.read_csv("cohere.csv")
gemini = pd.read_csv("gemini.csv")

# Normalize problem_id so merge works properly
for df in [original, cohere, gemini]:
    df["problem_id"] = df["problem_id"].astype(str).str.strip()

# Merge predictions with ground truth
cohere_merged = original.merge(cohere, on="problem_id", how="left", suffixes=("_true", "_pred"))
gemini_merged = original.merge(gemini, on="problem_id", how="left", suffixes=("_true", "_pred"))

# Function to clean answer fields for comparison
def clean(x):
    if pd.isna(x):
        return None
    x = str(x).strip()
    x = x.replace(" ", "")
    x = x.replace("\\\\", "")
    x = x.replace("\n", "")
    return x

cohere_merged["answer_true_clean"] = cohere_merged["answer_true"].apply(clean)
cohere_merged["answer_pred_clean"] = cohere_merged["answer_pred"].apply(clean)

gemini_merged["answer_true_clean"] = gemini_merged["answer_true"].apply(clean)
gemini_merged["answer_pred_clean"] = gemini_merged["answer_pred"].apply(clean)

# Function to compute accuracy and counts
def compute_accuracy(df):
    total = len(df)
    compared_df = df.dropna(subset=["answer_pred_clean"])
    compared_count = len(compared_df)
    skipped_count = total - compared_count

    overall_accuracy = (compared_df["answer_true_clean"] == compared_df["answer_pred_clean"]).mean()

    label_acc = compared_df.groupby("label").apply(
        lambda g: (g["answer_true_clean"] == g["answer_pred_clean"]).mean()
    )

    level_acc = compared_df.groupby("level").apply(
        lambda g: (g["answer_true_clean"] == g["answer_pred_clean"]).mean()
    )

    return overall_accuracy, label_acc, level_acc, total, compared_count, skipped_count

# Compute for APIs
cohere_acc, cohere_label_acc, cohere_level_acc, coh_total, coh_comp, coh_skip = compute_accuracy(cohere_merged)
gemini_acc, gemini_label_acc, gemini_level_acc, gem_total, gem_comp, gem_skip = compute_accuracy(gemini_merged)

# Print results
print("\n=== Cohere Accuracy ===")
print(f"Total problems: {coh_total}")
print(f"Compared (non-NA): {coh_comp}")
print(f"Skipped (NA predictions): {coh_skip}")
print("Overall Accuracy:", round(cohere_acc * 100, 2), "%")
print("\nAccuracy by Label:\n", cohere_label_acc)
print("\nAccuracy by Level:\n", cohere_level_acc)

print("\n=== Gemini Accuracy ===")
print(f"Total problems: {gem_total}")
print(f"Compared (non-NA): {gem_comp}")
print(f"Skipped (NA predictions): {gem_skip}")
print("Overall Accuracy:", round(gemini_acc * 100, 2), "%")
print("\nAccuracy by Label:\n", gemini_label_acc)
print("\nAccuracy by Level:\n", gemini_level_acc)
# Out:
# === Cohere Accuracy ===
# Total problems: 387
# Compared (non-NA): 387
# Skipped (NA predictions): 0
# Overall Accuracy: 28.42 %
#
# Accuracy by Label:
#  label
# Algebra                                0.258278
# Calculus                               0.400000
# Calculus and Analysis                  0.291667
# Combinatorics                          0.054054
# Differential Equations                 0.642857
# Geometry                               0.333333
# Linear Algebra and Abstract Algebra    0.200000
# NumberTheory                           0.000000
# PreCalculus                            0.595745
# Probability                            0.047619
# Series                                 0.000000
# Statistics                             0.235294
# Trigonometry                           0.000000
# dtype: float64
#
# Accuracy by Level:
#  level
# college math               0.257426
# high school competition    0.074324
# high school math           0.528986
# dtype: float64
#
# === Gemini Accuracy ===
# Total problems: 387
# Compared (non-NA): 234
# Skipped (NA predictions): 153
# Overall Accuracy: 32.91 %
#
# Accuracy by Label:
#  label
# Algebra                                0.269663
# Calculus                               0.666667
# Calculus and Analysis                  0.230769
# Combinatorics                          0.000000
# Differential Equations                 0.333333
# Geometry                               0.535714
# Linear Algebra and Abstract Algebra    0.250000
# PreCalculus                            0.724138
# Probability                            0.125000
# Series                                 1.000000
# Statistics                             0.400000
# dtype: float64
#
# Accuracy by Level:
#  level
# college math               0.241379
# high school competition    0.053763
# high school math           0.698795
# dtype: float64
